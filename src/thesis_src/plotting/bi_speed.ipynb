# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("ggplot")

# %%
from s4_playground.plotting.data.exp3.speed_test_annotated import data

# %%
data
# Out:
# {'s6_fused': {'mem_far': 0.51, 'mem_back': 2.14, 'far': 72.6, 'back': 18.8},
#  's6': {'mem_far': 0.55, 'mem_back': 2.9, 'far': 70.3, 'back': 17.1},
#  's6_bi': {'mem_far': 0.76, 'mem_back': 4.5, 'far': 42.0, 'back': 10.9},
#  's4d': {'mem_far': 0.92, 'mem_back': 5.0, 'far': 63.9, 'back': 14.9},
#  's4d_bi': {'mem_far': 0.97, 'mem_back': 5.81, 'far': 43.0, 'back': 10.0}}

# %%
import numpy as np

vars = ["far", "back", "mem_far", "mem_back"]
def plot_efficiency(var = "back"):
    names = [key for key in data.keys()]
    vals = np.array([data[key][var] for key in data.keys()])
    if "mem" in var:
        vals_normed = vals / np.sort(vals)[1]
    else:
        vals_normed = vals / np.sort(vals)[-2]
    # max_val = max([data[key][var] for key in data.keys()])
    # print(max_val)
    # max_val = {key[var] : [data[key][var]/max_val for key in data.keys()}
    plt.figure(figsize=(4,7))
    idx = 0
    idxs = []
    for name, val in zip(names, vals):
        if idx == 3: idx+=1
        if "fused" in name:
            color="royalblue"

        elif "bi" in name:
            color="indianred"
        else:
            color="cornflowerblue"
           
           
        plt.bar(idx, val, color=color, width=0.7, alpha=0.7)
        idx+=1
        idxs.append(idx)
    offset = -0.09
    for i in range(len(idxs)):
        if int(vals_normed[i]*100) >= 100: 
            plt.text(x = idxs[i]-1.3+offset, y = vals[i]+0.003*vals.max(), s=str(int(vals_normed[i]*100))[:4]+"%", c='black') 
        else:
            plt.text(x = idxs[i]-1.3, y = vals[i]+0.003*vals.max(), s=str(int(vals_normed[i]*100))[:4]+"%", c='black') 
            
    #     
    import matplotlib.patches as mpatches
    
    red_patch = [
                 mpatches.Patch(color='royalblue', label='Fused', alpha=0.7),
                 mpatches.Patch(color='cornflowerblue', label='Regular',alpha=0.7),
                 mpatches.Patch(color='indianred', label='Bidirectional',alpha=0.7)
                ]
    plt.legend(handles=red_patch, ncol=1)
    
    if var == "far":
        title = "Inference Speed\n(farward pass only)"
       
    elif var == "back":
        title = "Training Speed\n(farward & backward & optim step)"
       
    elif var == "mem_far":
        title = "Inference Memory\n(farward pass only)"   
       
    elif var in "mem_back":
        title = "Training Memory\n(farward & backward & optim step)"
    else:
        raise NameError
    
    if "mem" not in var:
        plt.ylabel("Batches / Sec")
    else:
        plt.ylabel("Memory - GB")
   
    plt.title(title)
    plt.grid(axis="x")
    plt.xticks([1, 4.5], ["Mamba-s6", "Mamba-s4d"])
    #plt.ylabel("normalized values")
    plt.tight_layout()
    title = title.replace(" ","")
    #plt.ylim(0,1.2)
    plt.savefig(f"data/exp3/{title}_bi_speed.png", dpi=200)
    plt.show()


for var in vars:
    plot_efficiency(var)
